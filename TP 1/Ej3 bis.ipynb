# %%
import numpy as np
import networkx as nx
import matplotlib.pylab as plt
import random

# G = nx.read_gml('as-22july06.gml')

# Grado=[]


# for grad in G.degree:
#     Grado.append(G.degree(grad[0]))

Grado.sort()

# for j in range(len(Grado)):
#     print(Grado[j])
    
# Que necesito apra grafdicar probabilidad?
#Casos totales
#print(len(G.degree()))

#Hasta que k tiene sentido calcular Pk?
#print(max(Grado))

#Cuales son los casos favorables? usa el count para eso
#print(Grado.count(1))

#Ya estamos, ahora hagamos la probabilidad

# Prob=[]

# for k in range(max(Grado)+1):
#     Pk=Grado.count(k)/len(G.degree)
#     Prob.append(Pk)

# K=np.arange(max(Grado)+1)

plt.plot(K,Prob)
plt.title("Gráfico de probabilidad en funcion de grado")
plt.xlabel("Grado K")
plt.ylabel("Probabilidad Pk")
plt.show()


plt.semilogy(K,Prob,"r")
plt.title("Gráfico de probabilidad en funcion de grado con logaritmo en y")
plt.xlabel("Grado K")
plt.ylabel("Probabilidad Pk")
plt.show()

plt.semilogx(K,Prob,"g")
plt.title("Gráfico de probabilidad en funcion de grado con logaritmo en x")
plt.xlabel("Grado K")
plt.ylabel("Probabilidad Pk")
plt.show()

plt.loglog(K,Prob,"y")
plt.title("Gráfico de probabilidad en funcion de grado con logaritmo en ambos")
plt.xlabel("Grado K")
plt.ylabel("Probabilidad Pk")
plt.show()
